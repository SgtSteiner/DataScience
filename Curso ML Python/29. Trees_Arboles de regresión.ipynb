# %% [markdown]
# # Arboles de Regresión

# %% [markdown]
# La diferencia entre un árbol de decisión y un árbol de regresión es que este último la variable objetivo se trata de una variable numérica continua, puede tomar cualquier valor real, a diferenci de la de un árbol de decisión que se trata una variable categórica.

# %%
from IPython.display import Image

# %%
Image(filename="./images/arboles_25.png")

# %%
Image(filename="./images/arboles_26.png")

# %%
Image(filename="./images/arboles_27.png")
