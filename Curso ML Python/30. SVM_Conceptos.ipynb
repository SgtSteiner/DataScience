# %% [markdown]
# # Support Vector Machines

# %%
from IPython.display import Image

# %%
Image(filename="./images/svm_01.png")

# %%
Image(filename="./images/svm_02.png")

# %%
Image(filename="./images/svm_03.png")
